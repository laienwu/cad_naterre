# %%
# %load_ext sql
# %sql mysql://root:azerty012345@localhost/sakila
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 'Connected: root@sakila'

# %% [markdown]
# Corriger le first_name de l'acteur `HARPO WILLIAMS` qui était accidentellement inséré à `GROUCHO WILLIAMS`

# %% [markdown]
# UPDATE actor SET  first_name = 'HARPO' WHERE first_name='GROUCHO' AND last_name='WILLIAMS';

# %%
# %%sql
# SELECT REPLACE('GROUCHO WILLIAMS','GROUCHO','HARPO');
# Out:
#  * mysql://root:***@localhost/sakila
# 1 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# select * from actor where first_name='HArpo' and last_name='williams';
# Out:
#  * mysql://root:***@localhost/sakila
# 0 rows affected.
# []

# %%
# %%sql
# update actor set first_name='GROUCHO' where actor_id=172
# Out:
#  * mysql://root:***@localhost/sakila
# 1 rows affected.
# []

# %%
# %%sql
# select * from actor where actor_id=172;
# Out:
#  * mysql://root:***@localhost/sakila
# 1 rows affected.
# [(172, 'GROUCHO', 'WILLIAMS', datetime.datetime(2006, 2, 15, 4, 34, 33))]

# %%
#%%sql
#SELECT * FROM actor WHERE first_name='HARPO' AND last_name='WILLIAMS';

# %% [markdown]
# Mettre à jour le first_name dans la table actor pour l'actor_id 173 comme suit:
# si le first_name ="ALAN" alors remplacer le par "ALLAN" sinon par "MUCHO ALLAN"

# %%
# %%sql
# UPDATE actor SET first_name=
# case
# WHEN first_name = 'ALAN' THEN 'ALLAN' ELSE 'MUCHO ALLAN' END
# WHERE actor_id =173;
# Out:
#  * mysql://root:***@localhost/sakila
# 1 rows affected.
# []

# %% [markdown]
# Trouver les first_names,last names et l'adresse de chacun des membre staff
# RQ: utiliser join avec les tables `staff` & `address`:

# %%
# %%sql
# #select * from staff;
# describe staff;

# %%
# %%sql
# describe address;

# %%
# %%sql
# SELECT first_name, last_name,address
# FROM staff as st
# LEFT JOIN address ad on st.address_id=ad.address_id;
# Out:
#  * mysql://root:***@localhost/sakila
# 2 rows affected.
# [('Mike', 'Hillyer', '23 Workhaven Lane'),
#  ('Jon', 'Stephens', '1411 Lillydale Drive')]

# %% [markdown]
# Afficher pour chaque membre du staff ,le total de ses salaires depuis Aout 2005.
# RQ: Utiliser les tables `staff` & `payment`.

# %%
# %%sql
# select * from payment order by payment_date asc limit 1;

# %%
# %%sql
# SELECT st.first_name,st.last_name,SUM(payment.amount) AS Total
# FROM staff as st
# LEFT JOIN payment ON st.staff_id=payment.staff_id
# WHERE payment.payment_date>='2005-08-01'
# GROUP BY st.staff_id
# Out:
#  * mysql://root:***@localhost/sakila
# 2 rows affected.
# [('Mike', 'Hillyer', Decimal('12087.74')),
#  ('Jon', 'Stephens', Decimal('12498.57'))]

# %% [markdown]
# Afficher pour chaque film ,le nombre de ses acteurs

# %%
# %%sql
# SELECT count(actor_id),title FROM film_actor
# LEFT JOIN film ON film.film_id = film_actor.film_id
# GROUP BY title;
# Out:
#  * mysql://root:***@localhost/sakila
# 997 rows affected.
# [(10, 'ACADEMY DINOSAUR'),
#  (4, 'ACE GOLDFINGER'),
#  (5, 'ADAPTATION HOLES'),
#  (5, 'AFFAIR PREJUDICE'),
#  (5, 'AFRICAN EGG'),
#  (7, 'AGENT TRUMAN'),
#  (5, 'AIRPLANE SIERRA'),
#  (4, 'AIRPORT POLLOCK'),
#  (9, 'ALABAMA DEVIL'),
#  (8, 'ALADDIN CALENDAR'),
#  (4, 'ALAMO VIDEOTAPE'),
#  (7, 'ALASKA PHANTOM'),
#  (5, 'ALI FOREVER'),
#  (4, 'ALICE FANTASIA'),
#  (6, 'ALIEN CENTER'),
#  (5, 'ALLEY EVOLUTION'),
#  (8, 'ALONE TRIP'),
#  (4, 'ALTER VICTORY'),
#  (6, 'AMADEUS HOLY'),
#  (6, 'AMELIE HELLFIGHTERS'),
#  (5, 'AMERICAN CIRCUS'),
#  (4, 'AMISTAD MIDSUMMER'),
#  (5, 'ANACONDA CONFESSIONS'),
#  (5, 'ANALYZE HOOSIERS'),
#  (9, 'ANGELS LIFE'),
#  (3, 'ANNIE IDENTITY'),
#  (9, 'ANONYMOUS HUMAN'),
#  (2, 'ANTHEM LUKE'),
#  (7, 'ANTITRUST TOMATOES'),
#  (3, 'ANYTHING SAVANNAH'),
#  (4, 'APACHE DIVINE'),
#  (5, 'APOCALYPSE FLAMINGOS'),
#  (8, 'APOLLO TEEN'),
#  (12, 'ARABIA DOGMA'),
#  (8, 'ARACHNOPHOBIA ROLLERCOASTER'),
# ...

# %% [markdown]
# Trouver le film intitulé "Hunchback Impossible"

# %%
# %%sql
# SELECT  film_id FROM film
# WHERE title='Hunchback Impossible'
# Out:
#  * mysql://root:***@localhost/sakila
# 1 rows affected.
# [(439,)]

# %% [markdown]
# combien de copies exist t il dans le systme d'inventaire pour le film `Hunchback Impossible`

# %%
# %%sql
# SELECT film_id, count(film_id) FROM inventory
# WHERE film_id=439
# Out:
#  * mysql://root:***@localhost/sakila
# 1 rows affected.
# [(439, 6)]

# %%
# %%sql
# SELECT film_id, count(film_id) as compte FROM inventory
# WHERE film_id in (SELECT  film_id FROM film WHERE title='Hunchback Impossible')
# group by film_id;
# Out:
#  * mysql://root:***@localhost/sakila
# 1 rows affected.
# [(439, 6)]

# %%
# %%sql
# SELECT film.title, COUNT(INV.film_id)
# FROM film
# INNER JOIN inventory as INV ON film.film_id = INV.film_id
# AND film.title = "Hunchback Impossible"
# Out:
#  * mysql://root:***@localhost/sakila
# 1 rows affected.
# [('HUNCHBACK IMPOSSIBLE', 6)]

# %%
# %%sql
# SELECT store_id, count(film_id)
# FROM inventory
# #INNER JOIN film on film.film_id=inventory.film_id
# WHERE film_id=439
# #AND film.title='Hunchback Impossible'
# group by store_id;
# Out:
#  * mysql://root:***@localhost/sakila
# 2 rows affected.
# [(1, 4), (2, 2)]

# %%
# %%sql
# select language_id from language where name='english'
# Out:
#  * mysql://root:***@localhost/sakila
# 1 rows affected.
# [(1,)]

# %% [markdown]
# Afficher les titres des films en anglais commençant par 'K' ou 'Q'

# %%
# %%sql
# SELECT title FROM film
# WHERE (title LIKE 'k%'
# OR title LIKE 'Q%')
# AND language_id =(select language_id from language where name='english');
# Out:
#  * mysql://root:***@localhost/sakila
# 15 rows affected.
# [('KANE EXORCIST',),
#  ('KARATE MOON',),
#  ('KENTUCKIAN GIANT',),
#  ('KICK SAVANNAH',),
#  ('KILL BROTHERHOOD',),
#  ('KILLER INNOCENT',),
#  ('KING EVOLUTION',),
#  ('KISS GLORY',),
#  ('KISSING DOLLS',),
#  ('KNOCK WARLOCK',),
#  ('KRAMER CHOCOLATE',),
#  ('KWAI HOMEWARD',),
#  ('QUEEN LUKE',),
#  ('QUEST MUSSOLINI',),
#  ('QUILLS BULL',)]

# %% [markdown]
# Afficher les first et last names des acteurs qui ont participé au film intitulé 'ACADEMY DINOSAUR'

# %%
# %%sql
# SELECT first_name, last_name
# FROM actor a
# LEFT JOIN film_actor f ON a.actor_id = f.actor_id
# WHERE film_id IN (SELECT film_id FROM film WHERE title = 'ACADEMY DINOSAUR');
# Out:
#  * mysql://root:***@localhost/sakila
# 10 rows affected.
# [('PENELOPE', 'GUINESS'),
#  ('CHRISTIAN', 'GABLE'),
#  ('LUCILLE', 'TRACY'),
#  ('SANDRA', 'PECK'),
#  ('JOHNNY', 'CAGE'),
#  ('MENA', 'TEMPLE'),
#  ('WARREN', 'NOLTE'),
#  ('OPRAH', 'KILMER'),
#  ('ROCK', 'DUKAKIS'),
#  ('MARY', 'KEITEL')]

# %%
# %%sql
# SELECT ACT.first_name, ACT.last_name, film.title
# FROM actor as ACT
# INNER JOIN film_actor as FA ON ACT.actor_id = FA.actor_id
# INNER JOIN film ON FA.film_id = film.film_id
# AND film.title = "ACADEMY DINOSAUR"
# Out:
#  * mysql://root:***@localhost/sakila
# 10 rows affected.
# [('PENELOPE', 'GUINESS', 'ACADEMY DINOSAUR'),
#  ('CHRISTIAN', 'GABLE', 'ACADEMY DINOSAUR'),
#  ('LUCILLE', 'TRACY', 'ACADEMY DINOSAUR'),
#  ('SANDRA', 'PECK', 'ACADEMY DINOSAUR'),
#  ('JOHNNY', 'CAGE', 'ACADEMY DINOSAUR'),
#  ('MENA', 'TEMPLE', 'ACADEMY DINOSAUR'),
#  ('WARREN', 'NOLTE', 'ACADEMY DINOSAUR'),
#  ('OPRAH', 'KILMER', 'ACADEMY DINOSAUR'),
#  ('ROCK', 'DUKAKIS', 'ACADEMY DINOSAUR'),
#  ('MARY', 'KEITEL', 'ACADEMY DINOSAUR')]

# %%
# %%sql
# SELECT actor.actor_id, actor.first_name, actor.last_name, film.title
# FROM film
#     JOIN film_actor
#         ON film.film_id = film_actor.film_id
#     JOIN actor
#         ON actor.actor_id = film_actor.actor_id
# WHERE film.title = 'ACADEMY DINOSAUR'
# Out:
#  * mysql://root:***@localhost/sakila
# 10 rows affected.
# [(1, 'PENELOPE', 'GUINESS', 'ACADEMY DINOSAUR'),
#  (10, 'CHRISTIAN', 'GABLE', 'ACADEMY DINOSAUR'),
#  (20, 'LUCILLE', 'TRACY', 'ACADEMY DINOSAUR'),
#  (30, 'SANDRA', 'PECK', 'ACADEMY DINOSAUR'),
#  (40, 'JOHNNY', 'CAGE', 'ACADEMY DINOSAUR'),
#  (53, 'MENA', 'TEMPLE', 'ACADEMY DINOSAUR'),
#  (108, 'WARREN', 'NOLTE', 'ACADEMY DINOSAUR'),
#  (162, 'OPRAH', 'KILMER', 'ACADEMY DINOSAUR'),
#  (188, 'ROCK', 'DUKAKIS', 'ACADEMY DINOSAUR'),
#  (198, 'MARY', 'KEITEL', 'ACADEMY DINOSAUR')]

# %%
# %%sql
# SELECT
#     first_name, last_name
# FROM
#     actor a
#         INNER JOIN
#     film_actor f ON a.actor_id = f.actor_id
# WHERE
#     film_id IN (SELECT
#             film_id
#         FROM
#             film
#         WHERE
# title = 'ACADEMY DINOSAUR');
# Out:
#  * mysql://root:***@localhost/sakila
# 10 rows affected.
# [('PENELOPE', 'GUINESS'),
#  ('CHRISTIAN', 'GABLE'),
#  ('LUCILLE', 'TRACY'),
#  ('SANDRA', 'PECK'),
#  ('JOHNNY', 'CAGE'),
#  ('MENA', 'TEMPLE'),
#  ('WARREN', 'NOLTE'),
#  ('OPRAH', 'KILMER'),
#  ('ROCK', 'DUKAKIS'),
#  ('MARY', 'KEITEL')]

# %% [markdown]
# Trouver la liste des film catégorisés comme  _family_ films.

# %%
# %%sql
# select category.name,film.title
# from  film_category
# left join film on film.film_id = film_category.film_id
# left join category on category.category_id = film_category.category_id
# where category.name = 'family';
# Out:
#  * mysql://root:***@localhost/sakila
# 69 rows affected.
# [('Family', 'AFRICAN EGG'),
#  ('Family', 'APACHE DIVINE'),
#  ('Family', 'ATLANTIS CAUSE'),
#  ('Family', 'BAKED CLEOPATRA'),
#  ('Family', 'BANG KWAI'),
#  ('Family', 'BEDAZZLED MARRIED'),
#  ('Family', 'BILKO ANONYMOUS'),
#  ('Family', 'BLANKET BEVERLY'),
#  ('Family', 'BLOOD ARGONAUTS'),
#  ('Family', 'BLUES INSTINCT'),
#  ('Family', 'BRAVEHEART HUMAN'),
#  ('Family', 'CHASING FIGHT'),
#  ('Family', 'CHISUM BEHAVIOR'),
#  ('Family', 'CHOCOLAT HARRY'),
#  ('Family', 'CONFUSED CANDLES'),
#  ('Family', 'CONVERSATION DOWNHILL'),
#  ('Family', 'DATE SPEED'),
#  ('Family', 'DINOSAUR SECRETARY'),
#  ('Family', 'DUMBO LUST'),
#  ('Family', 'EARRING INSTINCT'),
#  ('Family', 'EFFECT GLADIATOR'),
#  ('Family', 'FEUD FROGMEN'),
#  ('Family', 'FINDING ANACONDA'),
#  ('Family', 'GABLES METROPOLIS'),
#  ('Family', 'GANDHI KWAI'),
#  ('Family', 'GLADIATOR WESTWARD'),
#  ('Family', 'GREASE YOUTH'),
#  ('Family', 'HALF OUTFIELD'),
# ...

# %% [markdown]
# Afficher le top 5 des films les plus loués par ordre decroissant

# %%
# %%sql
# SELECT film.title, COUNT(rental.inventory_id) AS Count_of_Rented_Movies
# FROM film
# JOIN inventory ON film.film_id = inventory.film_id
# JOIN rental ON inventory.inventory_id = rental.inventory_id
# GROUP BY film.film_id ORDER BY 2 DESC LIMIT 5;
# Out:
#  * mysql://root:***@localhost/sakila
# 5 rows affected.
# [('BUCKET BROTHERHOOD', 34),
#  ('ROCKETEER MOTHER', 33),
#  ('JUGGLER HARDLY', 32),
#  ('SCALAWAG DUCK', 32),
#  ('FORWARD TEMPLE', 32)]

# %%
# %%sql
# SELECT film.title, COUNT(rental.inventory_id)
# FROM film
# JOIN inventory ON film.film_id = inventory.film_id
# JOIN rental ON inventory.inventory_id = rental.inventory_id
# GROUP BY film.film_id
# ORDER BY COUNT(rental.inventory_id) DESC LIMIT 5;
# Out:
#  * mysql://root:***@localhost/sakila
# 5 rows affected.
# [('BUCKET BROTHERHOOD', 34),
#  ('ROCKETEER MOTHER', 33),
#  ('JUGGLER HARDLY', 32),
#  ('SCALAWAG DUCK', 32),
#  ('FORWARD TEMPLE', 32)]

# %% [markdown]
# Afficher la liste des stores : store ID, city, country

# %%
# %%sql
# SELECT store_id, city, country FROM store JOIN address ON address.address_id = store.address_id JOIN city ON city.city_id = address.city_id JOIN country ON country.country_id = city.country_id;

# %% [markdown]
# Afficher le chiffre d'affaire  par store.
# RQ: le chiffre d'affaire = somme (amount)

# %%
# %%sql
# SELECT store.store_id, SUM(payment.amount) FROM store JOIN staff ON store.store_id = staff.store_id JOIN payment ON payment.staff_id = staff.staff_id GROUP BY store.store_id;

# %% [markdown]
# Lister par ordre décroissant le top 5 des catégories ayant le plus des revenues.
# RQ utiliser les tables : category, film_category, inventory, payment, et rental.

# %%
# %%sql
# describe rental;

# %%
# %%sql
# describe film;

# %%
# %%sql
# describe payment;

# %%
# %%sql
# describe inventory;

# %%
# %%sql
# SELECT c.category_id, c.name,SUM(p.amount) 'Total return' FROM category c
# LEFT JOIN film_category fc ON c.category_id = fc.category_id
# LEFT JOIN inventory i ON fc.film_id = i.film_id
# LEFT JOIN rental r ON i.inventory_id = r.inventory_id
# LEFT JOIN payment p ON r.rental_id = p.rental_id
# GROUP BY c.category_id
# ORDER BY SUM(p.amount) DESC
# LIMIT 5;

# %% [markdown]
#  Créer une view top_five_genres avec les résultat de la requete precedante.

# %%
# %%sql
# CREATE VIEW top_five_genres AS
# SELECT name AS "Top Five", SUM(amount) AS "Gross"
# FROM category
# INNER JOIN film_category ON category.category_id = film_category.category_id
# INNER JOIN inventory ON inventory.film_id=film_category.film_id
# INNER JOIN rental ON rental.inventory_id=inventory.inventory_id
# INNER JOIN payment ON payment.rental_id=rental.rental_id
# GROUP BY name
# ORDER BY sum(amount)
# DESC limit 5;
# Out:
#  * mysql://root:***@localhost/sakila
# 0 rows affected.
# []

# %%
# %%sql
# SELECT * FROM top_five_genres;
# Out:
#  * mysql://root:***@localhost/sakila
# 5 rows affected.
# [('Sports', Decimal('5314.21')),
#  ('Sci-Fi', Decimal('4756.98')),
#  ('Animation', Decimal('4656.30')),
#  ('Drama', Decimal('4587.39')),
#  ('Comedy', Decimal('4383.58'))]

# %%
# %%sql
# describe sak;
# Out:
#  * mysql://root:***@localhost/sakila
# (MySQLdb._exceptions.ProgrammingError) (1146, "Table 'sakila.sakila' doesn't exist")
# [SQL: describe sakila;]
# (Background on this error at: http://sqlalche.me/e/f405)

# %% [markdown]
# Supprimer la table top_five_genres

# %%
# %%sql
# DROP VIEW IF EXISTS sakila.top_five_genres;
# Out:
#  * mysql://root:***@localhost/sakila
# 0 rows affected.
# []
